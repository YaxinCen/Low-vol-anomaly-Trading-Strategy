# %%
import pandas as pd
import numpy as np
import datetime
import time

# %%
datetime.datetime(1963,7,31), datetime.datetime(2018, 6, 29, 0, 0)
# Out:
# (datetime.datetime(1963, 7, 31, 0, 0), datetime.datetime(2018, 6, 29, 0, 0))

# %%
data = pd.read_csv('div_filled.csv', low_memory=False)

# %%
data
# Out:
#          PERMNO        date    DIVAMT        PRC    SHROUT datetime date
# 0         10000  1985/12/31  0.000000    0.00000       0.0    1985-12-31
# 1         10000  1986/01/31  0.000000    4.37500    3680.0    1986-01-31
# 2         10000  1986/02/28  0.000000    3.25000    3680.0    1986-02-28
# 3         10000  1986/03/31  0.000000    4.43750    3680.0    1986-03-31
# 4         10000  1986/04/30  0.000000    4.00000    3793.0    1986-04-30
# 5         10000  1986/05/30  0.000000    3.10938    3793.0    1986-05-30
# 6         10000  1986/06/30  0.000000    3.09375    3793.0    1986-06-30
# 7         10000  1986/07/31  0.000000    2.84375    3793.0    1986-07-31
# 8         10000  1986/08/29  0.000000    1.09375    3793.0    1986-08-29
# 9         10000  1986/09/30  0.000000    1.03125    3793.0    1986-09-30
# 10        10000  1986/10/31  0.000000    0.78125    3843.0    1986-10-31
# 11        10000  1986/11/28  0.000000    0.82813    3843.0    1986-11-28
# 12        10000  1986/12/31  0.000000    0.51563    3843.0    1986-12-31
# 13        10000  1987/01/30  0.000000    0.40625    3893.0    1987-01-30
# 14        10000  1987/02/27  0.000000    0.40625    3893.0    1987-02-27
# 15        10000  1987/03/31  0.000000    0.25000    3893.0    1987-03-31
# 16        10000  1987/04/30  0.000000    0.23438    3893.0    1987-04-30
# 17        10000  1987/05/29  0.000000    0.21875    3893.0    1987-05-29
# 18        10000  1987/06/30  0.000000    0.00000    3893.0    1987-06-30
# 19        10001  1985/12/31  0.000000    0.00000       0.0    1985-12-31
# 20        10001  1986/01/31  0.000000    6.12500     985.0    1986-01-31
# 21        10001  1986/02/28  0.000000    6.25000     985.0    1986-02-28
# 22        10001  1986/03/31  0.031667    6.31250     985.0    1986-03-31
# 23        10001  1986/04/30  0.031667    6.37500     985.0    1986-04-30
# 24        10001  1986/05/30  0.031667    6.31250     985.0    1986-05-30
# 25        10001  1986/06/30  0.035000    6.12500     985.0    1986-06-30
# 26        10001  1986/07/31  0.035000    6.06250     985.0    1986-07-31
# 27        10001  1986/08/29  0.035000    6.50000     985.0    1986-08-29
# 28        10001  1986/09/30  0.035000    6.37500     991.0    1986-09-30
# 29        10001  1986/10/31  0.035000    6.62500     991.0    1986-10-31
# ...         ...         ...       ...        ...       ...           ...
# 4098016   93436  2016/01/29  0.000000  191.20000  132056.0    2016-01-29
# 4098017   93436  2016/02/29  0.000000  191.92999  132056.0    2016-02-29
# 4098018   93436  2016/03/31  0.000000  229.77000  133858.0    2016-03-31
# 4098019   93436  2016/04/29  0.000000  240.75999  133945.0    2016-04-29
# 4098020   93436  2016/05/31  0.000000  223.23000  147543.0    2016-05-31
# 4098021   93436  2016/06/30  0.000000  212.28000  148015.0    2016-06-30
# 4098022   93436  2016/07/29  0.000000  234.78999  148693.0    2016-07-29
# 4098023   93436  2016/08/31  0.000000  212.00999  149239.0    2016-08-31
# 4098024   93436  2016/09/30  0.000000  204.03000  149825.0    2016-09-30
# 4098025   93436  2016/10/31  0.000000  197.73000  149891.0    2016-10-31
# 4098026   93436  2016/11/30  0.000000  189.39999  149964.0    2016-11-30
# 4098027   93436  2016/12/30  0.000000  213.69000  161561.0    2016-12-30
# 4098028   93436  2017/01/31  0.000000  251.92999  161670.0    2017-01-31
# 4098029   93436  2017/02/28  0.000000  249.99001  161670.0    2017-02-28
# 4098030   93436  2017/03/31  0.000000  278.29999  164164.0    2017-03-31
# 4098031   93436  2017/04/28  0.000000  314.07001  164260.0    2017-04-28
# 4098032   93436  2017/05/31  0.000000  341.01001  164260.0    2017-05-31
# 4098033   93436  2017/06/30  0.000000  361.60999  166863.0    2017-06-30
# 4098034   93436  2017/07/31  0.000000  323.47000  166887.0    2017-07-31
# 4098035   93436  2017/08/31  0.000000  355.89999  166887.0    2017-08-31
# 4098036   93436  2017/09/29  0.000000  341.10001  168017.0    2017-09-29
# 4098037   93436  2017/10/31  0.000000  331.53000  168067.0    2017-10-31
# 4098038   93436  2017/11/30  0.000000  308.85001  168067.0    2017-11-30
# 4098039   93436  2017/12/29  0.000000  311.35001  168797.0    2017-12-29
# 4098040   93436  2018/01/31  0.000000  354.31000  168797.0    2018-01-31
# 4098041   93436  2018/02/28  0.000000  343.06000  168920.0    2018-02-28
# 4098042   93436  2018/03/29  0.000000  266.13000  169750.0    2018-03-29
# 4098043   93436  2018/04/30  0.000000  293.89999  169794.0    2018-04-30
# 4098044   93436  2018/05/31  0.000000  284.73001  169794.0    2018-05-31
# 4098045   93436  2018/06/29  0.000000  342.95001  170516.0    2018-06-29
#
# [4098046 rows x 6 columns]

# %%
data['PRC'] = data['PRC'].fillna(0)
data['SHROUT'] = data['SHROUT'].fillna(0)

# %%
head, mid, tail = [], [], []

for i1 in range(1964, 2018):
    for i2 in range(2,13):
        mid.append(datetime.datetime(i1, i2, 1)-datetime.timedelta(days = 1))
    mid.append(datetime.datetime(i1+1, 1, 1)-datetime.timedelta(days = 1))

for i1 in range(8, 13):
    head.append(datetime.datetime(1963, i1, 1)-datetime.timedelta(days = 1))
head.append(datetime.datetime(1964, 1, 1)-datetime.timedelta(days = 1))
    
for i1 in range(2, 8):
    tail.append(datetime.datetime(2018,i1,1)-datetime.timedelta(days = 1))

dates_month = head+mid+tail # The index of the data file, in months

# %%
# make sure the dates are aligned to the last day of the month
def find_match_date(date):
    date = datetime.datetime.strptime(date,'%Y/%m/%d')
    if date not in dates_month:
        if date.month<=11:
            return datetime.datetime(date.year, date.month+1, 1) - datetime.timedelta(days=1)
        else:
            return datetime.datetime(date.year+1, 1, 1) - datetime.timedelta(days=1)
    else:
        return date

data['date'] = data['date'].apply(find_match_date)
data
# Out:
#          PERMNO       date    DIVAMT        PRC    SHROUT datetime date
# 0         10000 1985-12-31  0.000000    0.00000       0.0    1985-12-31
# 1         10000 1986-01-31  0.000000    4.37500    3680.0    1986-01-31
# 2         10000 1986-02-28  0.000000    3.25000    3680.0    1986-02-28
# 3         10000 1986-03-31  0.000000    4.43750    3680.0    1986-03-31
# 4         10000 1986-04-30  0.000000    4.00000    3793.0    1986-04-30
# 5         10000 1986-05-31  0.000000    3.10938    3793.0    1986-05-30
# 6         10000 1986-06-30  0.000000    3.09375    3793.0    1986-06-30
# 7         10000 1986-07-31  0.000000    2.84375    3793.0    1986-07-31
# 8         10000 1986-08-31  0.000000    1.09375    3793.0    1986-08-29
# 9         10000 1986-09-30  0.000000    1.03125    3793.0    1986-09-30
# 10        10000 1986-10-31  0.000000    0.78125    3843.0    1986-10-31
# 11        10000 1986-11-30  0.000000    0.82813    3843.0    1986-11-28
# 12        10000 1986-12-31  0.000000    0.51563    3843.0    1986-12-31
# 13        10000 1987-01-31  0.000000    0.40625    3893.0    1987-01-30
# 14        10000 1987-02-28  0.000000    0.40625    3893.0    1987-02-27
# 15        10000 1987-03-31  0.000000    0.25000    3893.0    1987-03-31
# 16        10000 1987-04-30  0.000000    0.23438    3893.0    1987-04-30
# 17        10000 1987-05-31  0.000000    0.21875    3893.0    1987-05-29
# 18        10000 1987-06-30  0.000000    0.00000    3893.0    1987-06-30
# 19        10001 1985-12-31  0.000000    0.00000       0.0    1985-12-31
# 20        10001 1986-01-31  0.000000    6.12500     985.0    1986-01-31
# 21        10001 1986-02-28  0.000000    6.25000     985.0    1986-02-28
# 22        10001 1986-03-31  0.031667    6.31250     985.0    1986-03-31
# 23        10001 1986-04-30  0.031667    6.37500     985.0    1986-04-30
# 24        10001 1986-05-31  0.031667    6.31250     985.0    1986-05-30
# 25        10001 1986-06-30  0.035000    6.12500     985.0    1986-06-30
# 26        10001 1986-07-31  0.035000    6.06250     985.0    1986-07-31
# 27        10001 1986-08-31  0.035000    6.50000     985.0    1986-08-29
# 28        10001 1986-09-30  0.035000    6.37500     991.0    1986-09-30
# 29        10001 1986-10-31  0.035000    6.62500     991.0    1986-10-31
# ...         ...        ...       ...        ...       ...           ...
# 4098016   93436 2016-01-31  0.000000  191.20000  132056.0    2016-01-29
# 4098017   93436 2016-02-29  0.000000  191.92999  132056.0    2016-02-29
# 4098018   93436 2016-03-31  0.000000  229.77000  133858.0    2016-03-31
# 4098019   93436 2016-04-30  0.000000  240.75999  133945.0    2016-04-29
# 4098020   93436 2016-05-31  0.000000  223.23000  147543.0    2016-05-31
# 4098021   93436 2016-06-30  0.000000  212.28000  148015.0    2016-06-30
# 4098022   93436 2016-07-31  0.000000  234.78999  148693.0    2016-07-29
# 4098023   93436 2016-08-31  0.000000  212.00999  149239.0    2016-08-31
# 4098024   93436 2016-09-30  0.000000  204.03000  149825.0    2016-09-30
# 4098025   93436 2016-10-31  0.000000  197.73000  149891.0    2016-10-31
# 4098026   93436 2016-11-30  0.000000  189.39999  149964.0    2016-11-30
# 4098027   93436 2016-12-31  0.000000  213.69000  161561.0    2016-12-30
# 4098028   93436 2017-01-31  0.000000  251.92999  161670.0    2017-01-31
# 4098029   93436 2017-02-28  0.000000  249.99001  161670.0    2017-02-28
# 4098030   93436 2017-03-31  0.000000  278.29999  164164.0    2017-03-31
# 4098031   93436 2017-04-30  0.000000  314.07001  164260.0    2017-04-28
# 4098032   93436 2017-05-31  0.000000  341.01001  164260.0    2017-05-31
# 4098033   93436 2017-06-30  0.000000  361.60999  166863.0    2017-06-30
# 4098034   93436 2017-07-31  0.000000  323.47000  166887.0    2017-07-31
# 4098035   93436 2017-08-31  0.000000  355.89999  166887.0    2017-08-31
# 4098036   93436 2017-09-30  0.000000  341.10001  168017.0    2017-09-29
# 4098037   93436 2017-10-31  0.000000  331.53000  168067.0    2017-10-31
# 4098038   93436 2017-11-30  0.000000  308.85001  168067.0    2017-11-30
# 4098039   93436 2017-12-31  0.000000  311.35001  168797.0    2017-12-29
# 4098040   93436 2018-01-31  0.000000  354.31000  168797.0    2018-01-31
# 4098041   93436 2018-02-28  0.000000  343.06000  168920.0    2018-02-28
# 4098042   93436 2018-03-31  0.000000  266.13000  169750.0    2018-03-29
# 4098043   93436 2018-04-30  0.000000  293.89999  169794.0    2018-04-30
# 4098044   93436 2018-05-31  0.000000  284.73001  169794.0    2018-05-31
# 4098045   93436 2018-06-30  0.000000  342.95001  170516.0    2018-06-29
#
# [4098046 rows x 6 columns]

# %%
# Record dates
cur_tic = data['PERMNO'][0]
start_ind = 0
dates_ind = {}
dates = {}

for i in range(len(data)):
    if data['PERMNO'][i]==cur_tic:
        pass
    else:
        dates_ind.update({cur_tic:[start_ind, i-1]})
        dates.update({cur_tic:[data['date'][start_ind],data['date'][i-1]]})
        start_ind=i
        cur_tic = data['PERMNO'][i]
        
dates_ind.update({cur_tic:[start_ind, i-1]})
dates.update({cur_tic:[data['date'][start_ind],data['date'][i-1]]})

# %%
dates
# Out:
# {10000: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1987, 6, 30, 0, 0)],
#  10001: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2017, 8, 31, 0, 0)],
#  10002: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  10003: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1995, 12, 29, 0, 0)],
#  10005: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1991, 7, 31, 0, 0)],
#  10006: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1984, 6, 29, 0, 0)],
#  10007: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10008: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10009: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2000, 11, 30, 0, 0)],
#  10010: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1995, 8, 31, 0, 0)],
#  10011: [datetime.datetime(1988, 5, 31, 0, 0),
#   datetime.datetime(1998, 2, 27, 0, 0)],
#  10012: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2005, 8, 31, 0, 0)],
#  10013: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1987, 6, 30, 0, 0)],
#  10014: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1977, 4, 29, 0, 0)],
#  10015: [datetime.datetime(1983, 8, 31, 0, 0),
#   datetime.datetime(1986, 7, 31, 0, 0)],
#  10016: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2001, 5, 31, 0, 0)],
#  10017: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10018: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1995, 11, 30, 0, 0)],
#  10019: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2002, 6, 28, 0, 0)],
#  10020: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1993, 5, 28, 0, 0)],
#  10021: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1996, 1, 31, 0, 0)],
#  10023: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1973, 6, 29, 0, 0)],
#  10024: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(1992, 5, 29, 0, 0)],
#  10025: [datetime.datetime(1985, 12, 31, 0, 0),
#   datetime.datetime(2017, 1, 31, 0, 0)],
#  10026: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10027: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1990, 3, 30, 0, 0)],
#  10028: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10029: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  10030: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1968, 12, 31, 0, 0)],
#  10031: [datetime.datetime(1983, 11, 30, 0, 0),
#   datetime.datetime(1989, 8, 31, 0, 0)],
#  10032: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10033: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1986, 12, 31, 0, 0)],
#  10034: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1991, 9, 30, 0, 0)],
#  10035: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2003, 12, 31, 0, 0)],
#  10036: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1991, 3, 28, 0, 0)],
#  10037: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2004, 6, 30, 0, 0)],
#  10038: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1991, 1, 31, 0, 0)],
#  10039: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2001, 6, 29, 0, 0)],
#  10040: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1989, 6, 30, 0, 0)],
#  10041: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10042: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2008, 3, 31, 0, 0)],
#  10043: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1999, 6, 30, 0, 0)],
#  10044: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10045: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1987, 4, 30, 0, 0)],
#  10046: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1995, 3, 31, 0, 0)],
#  10047: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1995, 1, 31, 0, 0)],
#  10048: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1999, 10, 29, 0, 0)],
#  10050: [datetime.datetime(1972, 12, 29, 0, 0),
#   datetime.datetime(1979, 6, 29, 0, 0)],
#  10051: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10052: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1988, 3, 31, 0, 0)],
#  10053: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1990, 1, 31, 0, 0)],
#  10054: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1987, 1, 30, 0, 0)],
#  10055: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1995, 8, 31, 0, 0)],
#  10056: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(2006, 10, 31, 0, 0)],
#  10057: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1996, 7, 31, 0, 0)],
#  10058: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1984, 9, 28, 0, 0)],
#  10059: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1994, 4, 29, 0, 0)],
#  10060: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1998, 6, 30, 0, 0)],
#  10061: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  10062: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1999, 9, 30, 0, 0)],
#  10063: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1993, 7, 30, 0, 0)],
#  10064: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1997, 3, 31, 0, 0)],
#  10065: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10066: [datetime.datetime(1983, 7, 29, 0, 0),
#   datetime.datetime(2008, 1, 31, 0, 0)],
#  10067: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1987, 3, 31, 0, 0)],
#  10068: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1988, 3, 31, 0, 0)],
#  10069: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1987, 1, 30, 0, 0)],
#  10070: [datetime.datetime(1986, 1, 31, 0, 0),
#   datetime.datetime(1990, 11, 30, 0, 0)],
#  10071: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1997, 9, 30, 0, 0)],
#  10072: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1992, 10, 30, 0, 0)],
#  10074: [datetime.datetime(1981, 12, 31, 0, 0),
#   datetime.datetime(1996, 3, 29, 0, 0)],
#  10075: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1999, 7, 30, 0, 0)],
#  10076: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10077: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1994, 1, 31, 0, 0)],
#  10078: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2010, 1, 29, 0, 0)],
#  10079: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1995, 3, 31, 0, 0)],
#  10080: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2003, 11, 28, 0, 0)],
#  10082: [datetime.datetime(1983, 2, 28, 0, 0),
#   datetime.datetime(1995, 9, 29, 0, 0)],
#  10083: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1993, 9, 30, 0, 0)],
#  10084: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1994, 3, 31, 0, 0)],
#  10085: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2006, 4, 28, 0, 0)],
#  10086: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1994, 7, 29, 0, 0)],
#  10087: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2000, 10, 31, 0, 0)],
#  10088: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1988, 5, 31, 0, 0)],
#  10089: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2005, 3, 31, 0, 0)],
#  10090: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1995, 8, 31, 0, 0)],
#  10091: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1989, 2, 28, 0, 0)],
#  10092: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2010, 5, 28, 0, 0)],
#  10093: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10094: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1997, 12, 31, 0, 0)],
#  10095: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1994, 12, 30, 0, 0)],
#  10096: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1990, 3, 30, 0, 0)],
#  10097: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1996, 4, 30, 0, 0)],
#  10098: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1989, 4, 28, 0, 0)],
#  10099: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1987, 9, 30, 0, 0)],
#  10100: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2013, 3, 28, 0, 0)],
#  10101: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1988, 7, 29, 0, 0)],
#  10102: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1978, 5, 31, 0, 0)],
#  10103: [datetime.datetime(1977, 2, 28, 0, 0),
#   datetime.datetime(1989, 12, 29, 0, 0)],
#  10104: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10105: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1987, 8, 31, 0, 0)],
#  10106: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1995, 1, 31, 0, 0)],
#  10107: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10108: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2005, 8, 31, 0, 0)],
#  10109: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  10111: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1973, 3, 30, 0, 0)],
#  10112: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10113: [datetime.datetime(2010, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10114: [datetime.datetime(1988, 5, 31, 0, 0),
#   datetime.datetime(2004, 8, 31, 0, 0)],
#  10115: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10116: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2017, 2, 28, 0, 0)],
#  10117: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1987, 10, 30, 0, 0)],
#  10118: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10119: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2007, 9, 28, 0, 0)],
#  10120: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1998, 5, 29, 0, 0)],
#  10121: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1992, 1, 31, 0, 0)],
#  10122: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2002, 10, 31, 0, 0)],
#  10123: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(2002, 6, 28, 0, 0)],
#  10124: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1987, 12, 31, 0, 0)],
#  10125: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1991, 8, 30, 0, 0)],
#  10126: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2000, 7, 31, 0, 0)],
#  10127: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2002, 4, 30, 0, 0)],
#  10128: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(2001, 2, 28, 0, 0)],
#  10130: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1999, 7, 30, 0, 0)],
#  10131: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1991, 9, 30, 0, 0)],
#  10132: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1989, 11, 30, 0, 0)],
#  10133: [datetime.datetime(1986, 2, 28, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10134: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10135: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1989, 2, 28, 0, 0)],
#  10136: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1996, 3, 29, 0, 0)],
#  10137: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2011, 2, 28, 0, 0)],
#  10138: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10139: [datetime.datetime(1988, 5, 31, 0, 0),
#   datetime.datetime(1989, 10, 31, 0, 0)],
#  10140: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1998, 7, 31, 0, 0)],
#  10141: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1996, 7, 31, 0, 0)],
#  10142: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2000, 4, 28, 0, 0)],
#  10143: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2010, 6, 30, 0, 0)],
#  10144: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10145: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10146: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1988, 4, 29, 0, 0)],
#  10147: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2016, 9, 30, 0, 0)],
#  10148: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1991, 4, 30, 0, 0)],
#  10149: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2002, 7, 31, 0, 0)],
#  10150: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1998, 2, 27, 0, 0)],
#  10151: [datetime.datetime(2010, 6, 30, 0, 0),
#   datetime.datetime(2015, 8, 31, 0, 0)],
#  10152: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10153: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10154: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  10155: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2001, 6, 29, 0, 0)],
#  10156: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1991, 5, 31, 0, 0)],
#  10157: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1997, 1, 31, 0, 0)],
#  10158: [datetime.datetime(2010, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10159: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10160: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2003, 6, 30, 0, 0)],
#  10161: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1993, 11, 30, 0, 0)],
#  10162: [datetime.datetime(1972, 12, 29, 0, 0),
#   datetime.datetime(1981, 3, 31, 0, 0)],
#  10163: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2012, 5, 31, 0, 0)],
#  10164: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1989, 9, 29, 0, 0)],
#  10165: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10166: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1992, 10, 30, 0, 0)],
#  10167: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1987, 6, 30, 0, 0)],
#  10168: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1989, 4, 28, 0, 0)],
#  10169: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1987, 9, 30, 0, 0)],
#  10170: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2003, 5, 30, 0, 0)],
#  10171: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10172: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1991, 12, 31, 0, 0)],
#  10173: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  10174: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1993, 3, 31, 0, 0)],
#  10175: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1997, 7, 31, 0, 0)],
#  10176: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1992, 6, 30, 0, 0)],
#  10177: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2003, 7, 31, 0, 0)],
#  10178: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1999, 2, 26, 0, 0)],
#  10179: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1997, 10, 31, 0, 0)],
#  10180: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10181: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1990, 3, 30, 0, 0)],
#  10182: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10183: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1986, 10, 31, 0, 0)],
#  10184: [datetime.datetime(1988, 2, 29, 0, 0),
#   datetime.datetime(1992, 4, 30, 0, 0)],
#  10185: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1999, 11, 30, 0, 0)],
#  10186: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1990, 4, 30, 0, 0)],
#  10187: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1998, 3, 31, 0, 0)],
#  10188: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1978, 8, 31, 0, 0)],
#  10189: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10190: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1992, 1, 31, 0, 0)],
#  10191: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1990, 3, 30, 0, 0)],
#  10192: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2001, 7, 31, 0, 0)],
#  10193: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1994, 8, 31, 0, 0)],
#  10194: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2000, 10, 31, 0, 0)],
#  10195: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2003, 9, 30, 0, 0)],
#  10196: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1968, 1, 31, 0, 0)],
#  10197: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1973, 2, 28, 0, 0)],
#  10198: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1991, 10, 31, 0, 0)],
#  10199: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1998, 4, 30, 0, 0)],
#  10200: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10201: [datetime.datetime(2010, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10202: [datetime.datetime(1986, 3, 31, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10203: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1993, 9, 30, 0, 0)],
#  10204: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 5, 29, 0, 0)],
#  10205: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2010, 12, 31, 0, 0)],
#  10206: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10207: [datetime.datetime(1988, 5, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10208: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 5, 29, 0, 0)],
#  10209: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1963, 10, 31, 0, 0)],
#  10210: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1991, 11, 29, 0, 0)],
#  10211: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2006, 3, 31, 0, 0)],
#  10212: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1996, 6, 28, 0, 0)],
#  10213: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1996, 12, 31, 0, 0)],
#  10214: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1998, 1, 30, 0, 0)],
#  10215: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 8, 31, 0, 0)],
#  10216: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2001, 5, 31, 0, 0)],
#  10217: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1970, 1, 30, 0, 0)],
#  10218: [datetime.datetime(1980, 9, 30, 0, 0),
#   datetime.datetime(1999, 3, 31, 0, 0)],
#  10219: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 5, 29, 0, 0)],
#  10220: [datetime.datetime(2010, 7, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10221: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10222: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  10223: [datetime.datetime(2010, 6, 30, 0, 0),
#   datetime.datetime(2014, 3, 31, 0, 0)],
#  10224: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1993, 5, 28, 0, 0)],
#  10225: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2014, 5, 30, 0, 0)],
#  10226: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1973, 10, 31, 0, 0)],
#  10227: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10228: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10229: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 3, 31, 0, 0)],
#  10230: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2001, 11, 30, 0, 0)],
#  10231: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1997, 9, 30, 0, 0)],
#  10232: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10233: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1986, 1, 31, 0, 0)],
#  10234: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1983, 7, 29, 0, 0)],
#  10235: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2001, 8, 31, 0, 0)],
#  10236: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10237: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10238: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2008, 2, 29, 0, 0)],
#  10239: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10240: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 5, 31, 0, 0)],
#  10241: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10242: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1998, 8, 31, 0, 0)],
#  10243: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1995, 4, 28, 0, 0)],
#  10244: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2002, 6, 28, 0, 0)],
#  10245: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 11, 30, 0, 0)],
#  10246: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1996, 3, 29, 0, 0)],
#  10247: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2000, 3, 31, 0, 0)],
#  10248: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  10249: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 10, 31, 0, 0)],
#  10250: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1997, 12, 31, 0, 0)],
#  10251: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 11, 30, 0, 0)],
#  10252: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10253: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10254: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 8, 31, 0, 0)],
#  10255: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10256: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2001, 7, 31, 0, 0)],
#  10257: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10258: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10259: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10260: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  10261: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1994, 1, 31, 0, 0)],
#  10262: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1990, 12, 31, 0, 0)],
#  10263: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1991, 1, 31, 0, 0)],
#  10264: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1989, 3, 31, 0, 0)],
#  10265: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 5, 29, 0, 0)],
#  10266: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1994, 8, 31, 0, 0)],
#  10267: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 8, 31, 0, 0)],
#  10268: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1974, 1, 31, 0, 0)],
#  10269: [datetime.datetime(1983, 6, 30, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10270: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 12, 31, 0, 0)],
#  10271: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2008, 9, 30, 0, 0)],
#  10272: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2012, 1, 31, 0, 0)],
#  10273: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 6, 30, 0, 0)],
#  10274: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1989, 9, 29, 0, 0)],
#  10275: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2004, 11, 30, 0, 0)],
#  10276: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1973, 2, 28, 0, 0)],
#  10277: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1978, 6, 30, 0, 0)],
#  10278: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1998, 3, 31, 0, 0)],
#  10279: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 1, 31, 0, 0)],
#  10280: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 7, 31, 0, 0)],
#  10281: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1998, 7, 31, 0, 0)],
#  10282: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1997, 1, 31, 0, 0)],
#  10283: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1987, 12, 31, 0, 0)],
#  10285: [datetime.datetime(1981, 9, 30, 0, 0),
#   datetime.datetime(1992, 1, 31, 0, 0)],
#  10286: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1997, 1, 31, 0, 0)],
#  10287: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 6, 30, 0, 0)],
#  10288: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10289: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(1990, 7, 31, 0, 0)],
#  10290: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2012, 5, 31, 0, 0)],
#  10291: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10293: [datetime.datetime(1983, 5, 31, 0, 0),
#   datetime.datetime(1985, 10, 31, 0, 0)],
#  10294: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10295: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10296: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1995, 1, 31, 0, 0)],
#  10297: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2017, 1, 31, 0, 0)],
#  10298: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 8, 31, 0, 0)],
#  10299: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2017, 3, 31, 0, 0)],
#  10300: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1992, 8, 31, 0, 0)],
#  10301: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10302: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10303: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2000, 6, 30, 0, 0)],
#  10304: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2010, 5, 28, 0, 0)],
#  10306: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1974, 10, 31, 0, 0)],
#  10307: [datetime.datetime(1986, 4, 30, 0, 0),
#   datetime.datetime(2000, 11, 30, 0, 0)],
#  10308: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10309: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1999, 7, 30, 0, 0)],
#  10310: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 7, 29, 0, 0)],
#  10311: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 7, 29, 0, 0)],
#  10312: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1986, 9, 30, 0, 0)],
#  10313: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1969, 1, 31, 0, 0)],
#  10314: [datetime.datetime(1980, 9, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10315: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10316: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1993, 6, 30, 0, 0)],
#  10317: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10318: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10319: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1994, 8, 31, 0, 0)],
#  10320: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1990, 12, 31, 0, 0)],
#  10321: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1987, 8, 31, 0, 0)],
#  10322: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 4, 30, 0, 0)],
#  10323: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1987, 8, 31, 0, 0)],
#  10324: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2011, 4, 29, 0, 0)],
#  10325: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2001, 5, 31, 0, 0)],
#  10326: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 9, 30, 0, 0)],
#  10327: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1990, 3, 30, 0, 0)],
#  10328: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 6, 30, 0, 0)],
#  10329: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1992, 4, 30, 0, 0)],
#  10330: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 12, 29, 0, 0)],
#  10331: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10332: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10333: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10334: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1990, 2, 28, 0, 0)],
#  10335: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 6, 30, 0, 0)],
#  10336: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 1, 31, 0, 0)],
#  10337: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 9, 30, 0, 0)],
#  10338: [datetime.datetime(1988, 5, 31, 0, 0),
#   datetime.datetime(1993, 3, 31, 0, 0)],
#  10339: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1995, 6, 30, 0, 0)],
#  10340: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1987, 9, 30, 0, 0)],
#  10341: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2004, 4, 30, 0, 0)],
#  10342: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2006, 3, 31, 0, 0)],
#  10343: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 1, 31, 0, 0)],
#  10344: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1994, 8, 31, 0, 0)],
#  10345: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1992, 7, 31, 0, 0)],
#  10346: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2002, 12, 31, 0, 0)],
#  10347: [datetime.datetime(1987, 12, 31, 0, 0),
#   datetime.datetime(1989, 10, 31, 0, 0)],
#  10349: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(2017, 7, 31, 0, 0)],
#  10350: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1993, 3, 31, 0, 0)],
#  10351: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  10352: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 3, 29, 0, 0)],
#  10353: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2016, 3, 31, 0, 0)],
#  10354: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 7, 31, 0, 0)],
#  10355: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10357: [datetime.datetime(1976, 4, 30, 0, 0),
#   datetime.datetime(1977, 1, 31, 0, 0)],
#  10358: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 4, 30, 0, 0)],
#  10359: [datetime.datetime(1988, 1, 29, 0, 0),
#   datetime.datetime(1989, 2, 28, 0, 0)],
#  10360: [datetime.datetime(1988, 2, 29, 0, 0),
#   datetime.datetime(1999, 8, 31, 0, 0)],
#  10361: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 5, 31, 0, 0)],
#  10362: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2006, 4, 28, 0, 0)],
#  10363: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10364: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1999, 11, 30, 0, 0)],
#  10365: [datetime.datetime(1982, 5, 28, 0, 0),
#   datetime.datetime(1985, 6, 28, 0, 0)],
#  10366: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1994, 6, 30, 0, 0)],
#  10367: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 3, 28, 0, 0)],
#  10368: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10369: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 3, 28, 0, 0)],
#  10370: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 3, 31, 0, 0)],
#  10371: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2010, 1, 29, 0, 0)],
#  10372: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1988, 7, 29, 0, 0)],
#  10373: [datetime.datetime(1984, 4, 30, 0, 0),
#   datetime.datetime(1985, 5, 31, 0, 0)],
#  10374: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 12, 31, 0, 0)],
#  10375: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10376: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 10, 31, 0, 0)],
#  10377: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10378: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10379: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 11, 30, 0, 0)],
#  10381: [datetime.datetime(1981, 7, 31, 0, 0),
#   datetime.datetime(1983, 5, 31, 0, 0)],
#  10382: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10383: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2008, 5, 30, 0, 0)],
#  10384: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 12, 31, 0, 0)],
#  10385: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1992, 5, 29, 0, 0)],
#  10386: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1999, 9, 30, 0, 0)],
#  10387: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 1, 31, 0, 0)],
#  10388: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2003, 3, 31, 0, 0)],
#  10389: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10390: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 1, 31, 0, 0)],
#  10391: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 10, 31, 0, 0)],
#  10392: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1993, 12, 31, 0, 0)],
#  10393: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1995, 3, 31, 0, 0)],
#  10394: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 4, 30, 0, 0)],
#  10395: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10396: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 3, 31, 0, 0)],
#  10397: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10398: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2000, 4, 28, 0, 0)],
#  10400: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1982, 5, 28, 0, 0)],
#  10401: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2005, 11, 30, 0, 0)],
#  10402: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1983, 4, 29, 0, 0)],
#  10403: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 5, 31, 0, 0)],
#  10404: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2010, 12, 31, 0, 0)],
#  10405: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 4, 28, 0, 0)],
#  10406: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1999, 4, 30, 0, 0)],
#  10407: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1998, 6, 30, 0, 0)],
#  10408: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10409: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1988, 9, 30, 0, 0)],
#  10410: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2000, 9, 29, 0, 0)],
#  10411: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1997, 4, 30, 0, 0)],
#  10412: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2000, 3, 31, 0, 0)],
#  10413: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1991, 7, 31, 0, 0)],
#  10414: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1994, 3, 31, 0, 0)],
#  10415: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1994, 1, 31, 0, 0)],
#  10416: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1989, 12, 29, 0, 0)],
#  10417: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1993, 5, 28, 0, 0)],
#  10418: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2004, 11, 30, 0, 0)],
#  10419: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1996, 12, 31, 0, 0)],
#  10420: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1992, 7, 31, 0, 0)],
#  10421: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10422: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2001, 9, 28, 0, 0)],
#  10423: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(2001, 8, 31, 0, 0)],
#  10424: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1987, 7, 31, 0, 0)],
#  10425: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1998, 7, 31, 0, 0)],
#  10426: [datetime.datetime(1986, 5, 30, 0, 0),
#   datetime.datetime(1995, 4, 28, 0, 0)],
#  10427: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10429: [datetime.datetime(1981, 9, 30, 0, 0),
#   datetime.datetime(1994, 9, 30, 0, 0)],
#  10430: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10431: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1993, 1, 29, 0, 0)],
#  10432: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1993, 12, 31, 0, 0)],
#  10433: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10434: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1997, 12, 31, 0, 0)],
#  10435: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  10436: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1971, 6, 30, 0, 0)],
#  10437: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 4, 28, 0, 0)],
#  10438: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1996, 6, 28, 0, 0)],
#  10439: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2000, 1, 31, 0, 0)],
#  10440: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10441: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 4, 30, 0, 0)],
#  10442: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2000, 7, 31, 0, 0)],
#  10443: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10445: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1980, 11, 28, 0, 0)],
#  10446: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1999, 5, 28, 0, 0)],
#  10447: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1992, 9, 30, 0, 0)],
#  10448: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 4, 29, 0, 0)],
#  10449: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2002, 9, 30, 0, 0)],
#  10450: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 4, 30, 0, 0)],
#  10451: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1997, 2, 28, 0, 0)],
#  10453: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(2005, 8, 31, 0, 0)],
#  10454: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1993, 10, 29, 0, 0)],
#  10455: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1998, 3, 31, 0, 0)],
#  10456: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2000, 6, 30, 0, 0)],
#  10457: [datetime.datetime(1988, 4, 29, 0, 0),
#   datetime.datetime(1997, 5, 30, 0, 0)],
#  10458: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1998, 7, 31, 0, 0)],
#  10459: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 3, 31, 0, 0)],
#  10460: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1997, 8, 29, 0, 0)],
#  10461: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1998, 8, 31, 0, 0)],
#  10462: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1997, 5, 30, 0, 0)],
#  10463: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10464: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 1, 31, 0, 0)],
#  10465: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 4, 30, 0, 0)],
#  10466: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10467: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2003, 1, 31, 0, 0)],
#  10468: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10469: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10470: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10471: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1992, 6, 30, 0, 0)],
#  10472: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10473: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1987, 8, 31, 0, 0)],
#  10474: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 5, 31, 0, 0)],
#  10475: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 11, 30, 0, 0)],
#  10476: [datetime.datetime(1988, 4, 29, 0, 0),
#   datetime.datetime(1993, 12, 31, 0, 0)],
#  10477: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1992, 10, 30, 0, 0)],
#  10478: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1992, 6, 30, 0, 0)],
#  10479: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1984, 2, 29, 0, 0)],
#  10480: [datetime.datetime(1983, 9, 30, 0, 0),
#   datetime.datetime(1984, 10, 31, 0, 0)],
#  10481: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1994, 10, 31, 0, 0)],
#  10482: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 2, 28, 0, 0)],
#  10483: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 8, 31, 0, 0)],
#  10484: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2001, 6, 29, 0, 0)],
#  10485: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10486: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 8, 30, 0, 0)],
#  10487: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1986, 6, 30, 0, 0)],
#  10488: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(2006, 4, 28, 0, 0)],
#  10489: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10490: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10491: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1990, 9, 28, 0, 0)],
#  10492: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1992, 10, 30, 0, 0)],
#  10493: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1995, 10, 31, 0, 0)],
#  10494: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1998, 12, 31, 0, 0)],
#  10495: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1977, 1, 31, 0, 0)],
#  10496: [datetime.datetime(1981, 2, 27, 0, 0),
#   datetime.datetime(1996, 8, 30, 0, 0)],
#  10497: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1987, 12, 31, 0, 0)],
#  10498: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 2, 28, 0, 0)],
#  10499: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 8, 31, 0, 0)],
#  10500: [datetime.datetime(1988, 4, 29, 0, 0),
#   datetime.datetime(1995, 7, 31, 0, 0)],
#  10501: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10502: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 7, 31, 0, 0)],
#  10503: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 1, 31, 0, 0)],
#  10504: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1992, 2, 28, 0, 0)],
#  10505: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 10, 31, 0, 0)],
#  10506: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1998, 3, 31, 0, 0)],
#  10507: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2014, 10, 31, 0, 0)],
#  10509: [datetime.datetime(1973, 2, 28, 0, 0),
#   datetime.datetime(1977, 9, 30, 0, 0)],
#  10510: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 5, 31, 0, 0)],
#  10511: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 6, 30, 0, 0)],
#  10512: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 6, 30, 0, 0)],
#  10513: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2000, 5, 31, 0, 0)],
#  10514: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10515: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1998, 12, 31, 0, 0)],
#  10516: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10517: [datetime.datetime(1982, 10, 29, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10518: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1987, 6, 30, 0, 0)],
#  10519: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1993, 3, 31, 0, 0)],
#  10520: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1994, 12, 30, 0, 0)],
#  10521: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10522: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 1, 31, 0, 0)],
#  10523: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 1, 31, 0, 0)],
#  10524: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1970, 12, 31, 0, 0)],
#  10525: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1980, 10, 31, 0, 0)],
#  10526: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 9, 29, 0, 0)],
#  10527: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1999, 9, 30, 0, 0)],
#  10528: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 8, 30, 0, 0)],
#  10529: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1988, 1, 29, 0, 0)],
#  10530: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10531: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2000, 11, 30, 0, 0)],
#  10532: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1965, 9, 30, 0, 0)],
#  10533: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1974, 5, 31, 0, 0)],
#  10534: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1991, 12, 31, 0, 0)],
#  10535: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1989, 8, 31, 0, 0)],
#  10536: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(2001, 4, 30, 0, 0)],
#  10537: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1995, 11, 30, 0, 0)],
#  10538: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1991, 8, 30, 0, 0)],
#  10539: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10541: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1978, 1, 31, 0, 0)],
#  10542: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1993, 3, 31, 0, 0)],
#  10543: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1991, 3, 28, 0, 0)],
#  10544: [datetime.datetime(1986, 6, 30, 0, 0),
#   datetime.datetime(1995, 9, 29, 0, 0)],
#  10545: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(2000, 7, 31, 0, 0)],
#  10546: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1993, 4, 30, 0, 0)],
#  10547: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10548: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  10549: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1989, 2, 28, 0, 0)],
#  10550: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10551: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1997, 3, 31, 0, 0)],
#  10552: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1989, 4, 28, 0, 0)],
#  10553: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1990, 9, 28, 0, 0)],
#  10554: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1987, 10, 30, 0, 0)],
#  10555: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1995, 8, 31, 0, 0)],
#  10556: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1991, 4, 30, 0, 0)],
#  10557: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1994, 5, 31, 0, 0)],
#  10558: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1988, 4, 29, 0, 0)],
#  10559: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1986, 10, 31, 0, 0)],
#  10560: [datetime.datetime(1987, 6, 30, 0, 0),
#   datetime.datetime(2007, 10, 31, 0, 0)],
#  10561: [datetime.datetime(1986, 7, 31, 0, 0),
#   datetime.datetime(1995, 10, 31, 0, 0)],
#  10562: [datetime.datetime(1986, 7, 31, 0, 0),
# ...
#   datetime.datetime(1995, 2, 28, 0, 0)],
#  10852: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1988, 5, 31, 0, 0)],
#  10853: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2016, 2, 29, 0, 0)],
#  10854: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1998, 2, 27, 0, 0)],
#  10855: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10856: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(1990, 11, 30, 0, 0)],
#  10857: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2000, 3, 31, 0, 0)],
#  10859: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1978, 10, 31, 0, 0)],
#  10860: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10861: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1990, 3, 30, 0, 0)],
#  10862: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1996, 3, 29, 0, 0)],
#  10863: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2001, 2, 28, 0, 0)],
#  10864: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1990, 9, 28, 0, 0)],
#  10865: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1989, 6, 30, 0, 0)],
#  10866: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10867: [datetime.datetime(1980, 11, 28, 0, 0),
#   datetime.datetime(1995, 10, 31, 0, 0)],
#  10868: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1992, 5, 29, 0, 0)],
#  10869: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1993, 8, 31, 0, 0)],
#  10870: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1998, 11, 30, 0, 0)],
#  10871: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1990, 2, 28, 0, 0)],
#  10872: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1994, 5, 31, 0, 0)],
#  10873: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1997, 3, 31, 0, 0)],
#  10874: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10875: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1996, 1, 31, 0, 0)],
#  10876: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2004, 1, 30, 0, 0)],
#  10877: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1990, 11, 30, 0, 0)],
#  10878: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(1998, 10, 30, 0, 0)],
#  10879: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1997, 7, 31, 0, 0)],
#  10880: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1996, 1, 31, 0, 0)],
#  10881: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2007, 4, 30, 0, 0)],
#  10883: [datetime.datetime(1984, 1, 31, 0, 0),
#   datetime.datetime(1986, 11, 28, 0, 0)],
#  10884: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1989, 7, 31, 0, 0)],
#  10885: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1990, 4, 30, 0, 0)],
#  10886: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10887: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  10888: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1994, 4, 29, 0, 0)],
#  10889: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1999, 1, 29, 0, 0)],
#  10890: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10891: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1981, 8, 31, 0, 0)],
#  10892: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10893: [datetime.datetime(1986, 10, 31, 0, 0),
#   datetime.datetime(1997, 12, 31, 0, 0)],
#  10894: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1991, 12, 31, 0, 0)],
#  10895: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1987, 11, 30, 0, 0)],
#  10896: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 7, 31, 0, 0)],
#  10897: [datetime.datetime(1988, 4, 29, 0, 0),
#   datetime.datetime(1995, 2, 28, 0, 0)],
#  10898: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1991, 5, 31, 0, 0)],
#  10899: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1989, 3, 31, 0, 0)],
#  10900: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1991, 10, 31, 0, 0)],
#  10901: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10902: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2000, 6, 30, 0, 0)],
#  10904: [datetime.datetime(1983, 12, 30, 0, 0),
#   datetime.datetime(1986, 10, 31, 0, 0)],
#  10905: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1998, 4, 30, 0, 0)],
#  10906: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2005, 3, 31, 0, 0)],
#  10907: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 4, 29, 0, 0)],
#  10908: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2004, 7, 30, 0, 0)],
#  10909: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10910: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 3, 31, 0, 0)],
#  10911: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1975, 10, 31, 0, 0)],
#  10912: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1991, 7, 31, 0, 0)],
#  10913: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10914: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1997, 7, 31, 0, 0)],
#  10915: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10916: [datetime.datetime(1988, 4, 29, 0, 0),
#   datetime.datetime(2007, 11, 30, 0, 0)],
#  10917: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10918: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1989, 5, 31, 0, 0)],
#  10919: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 10, 29, 0, 0)],
#  10920: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10921: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 4, 29, 0, 0)],
#  10922: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 5, 31, 0, 0)],
#  10923: [datetime.datetime(1988, 4, 29, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  10924: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2009, 2, 27, 0, 0)],
#  10925: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10926: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2006, 12, 29, 0, 0)],
#  10927: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1989, 7, 31, 0, 0)],
#  10928: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2002, 8, 30, 0, 0)],
#  10929: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1999, 3, 31, 0, 0)],
#  10930: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 2, 28, 0, 0)],
#  10931: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1995, 10, 31, 0, 0)],
#  10932: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10933: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10934: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1989, 8, 31, 0, 0)],
#  10935: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2005, 8, 31, 0, 0)],
#  10936: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1987, 12, 31, 0, 0)],
#  10937: [datetime.datetime(1988, 6, 30, 0, 0),
#   datetime.datetime(2006, 9, 29, 0, 0)],
#  10938: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1970, 12, 31, 0, 0)],
#  10939: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1973, 10, 31, 0, 0)],
#  10940: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1987, 10, 30, 0, 0)],
#  10941: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1996, 1, 31, 0, 0)],
#  10942: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2013, 2, 28, 0, 0)],
#  10943: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10944: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1992, 2, 28, 0, 0)],
#  10945: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1991, 1, 31, 0, 0)],
#  10947: [datetime.datetime(1983, 6, 30, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  10948: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 7, 29, 0, 0)],
#  10949: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 12, 30, 0, 0)],
#  10950: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1994, 5, 31, 0, 0)],
#  10951: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1989, 5, 31, 0, 0)],
#  10952: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10953: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1991, 10, 31, 0, 0)],
#  10955: [datetime.datetime(1973, 2, 28, 0, 0),
#   datetime.datetime(1975, 6, 30, 0, 0)],
#  10956: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1992, 6, 30, 0, 0)],
#  10957: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1997, 8, 29, 0, 0)],
#  10958: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 4, 30, 0, 0)],
#  10959: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1995, 5, 31, 0, 0)],
#  10960: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1990, 6, 29, 0, 0)],
#  10961: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2002, 11, 29, 0, 0)],
#  10963: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2000, 11, 30, 0, 0)],
#  10964: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 7, 30, 0, 0)],
#  10965: [datetime.datetime(1988, 1, 29, 0, 0),
#   datetime.datetime(1995, 3, 31, 0, 0)],
#  10966: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  10967: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  10968: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 2, 26, 0, 0)],
#  10969: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1996, 1, 31, 0, 0)],
#  10970: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1980, 2, 29, 0, 0)],
#  10971: [datetime.datetime(1972, 11, 30, 0, 0),
#   datetime.datetime(1981, 4, 30, 0, 0)],
#  10972: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2004, 5, 28, 0, 0)],
#  10973: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1988, 6, 30, 0, 0)],
#  10974: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2008, 2, 29, 0, 0)],
#  10975: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1992, 10, 30, 0, 0)],
#  10976: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 6, 30, 0, 0)],
#  10977: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2004, 4, 30, 0, 0)],
#  10978: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1998, 8, 31, 0, 0)],
#  10979: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1987, 7, 31, 0, 0)],
#  10980: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 12, 31, 0, 0)],
#  10981: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1994, 8, 31, 0, 0)],
#  10982: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1987, 11, 30, 0, 0)],
#  10983: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1995, 6, 30, 0, 0)],
#  10984: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2006, 3, 31, 0, 0)],
#  10985: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1989, 8, 31, 0, 0)],
#  10986: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1995, 5, 31, 0, 0)],
#  10987: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2002, 10, 31, 0, 0)],
#  10988: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1991, 3, 28, 0, 0)],
#  10989: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(2000, 10, 31, 0, 0)],
#  10990: [datetime.datetime(1975, 5, 30, 0, 0),
#   datetime.datetime(1987, 10, 30, 0, 0)],
#  10991: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 5, 28, 0, 0)],
#  10992: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1993, 2, 26, 0, 0)],
#  10993: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1994, 6, 30, 0, 0)],
#  10994: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(2009, 10, 30, 0, 0)],
#  10995: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1994, 9, 30, 0, 0)],
#  10996: [datetime.datetime(1986, 11, 28, 0, 0),
#   datetime.datetime(1987, 10, 30, 0, 0)],
#  10998: [datetime.datetime(1984, 2, 29, 0, 0),
#   datetime.datetime(1996, 12, 31, 0, 0)],
#  10999: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(2004, 5, 28, 0, 0)],
#  11000: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1998, 10, 30, 0, 0)],
#  11001: [datetime.datetime(1988, 5, 31, 0, 0),
#   datetime.datetime(1996, 7, 31, 0, 0)],
#  11002: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1988, 1, 29, 0, 0)],
#  11003: [datetime.datetime(2010, 6, 30, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  11004: [datetime.datetime(1988, 3, 31, 0, 0),
#   datetime.datetime(1995, 5, 31, 0, 0)],
#  11005: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(2002, 7, 31, 0, 0)],
#  11006: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  11007: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1992, 2, 28, 0, 0)],
#  11008: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1990, 7, 31, 0, 0)],
#  11010: [datetime.datetime(1975, 6, 30, 0, 0),
#   datetime.datetime(1993, 8, 31, 0, 0)],
#  11011: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1994, 10, 31, 0, 0)],
#  11012: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(2002, 2, 28, 0, 0)],
#  11013: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  11014: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1996, 8, 30, 0, 0)],
#  11015: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1989, 7, 31, 0, 0)],
#  11016: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1990, 10, 31, 0, 0)],
#  11017: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1992, 1, 31, 0, 0)],
#  11018: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(2018, 6, 29, 0, 0)],
#  11019: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1993, 12, 31, 0, 0)],
#  11020: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1999, 11, 30, 0, 0)],
#  11021: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1990, 12, 31, 0, 0)],
#  11022: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1994, 12, 30, 0, 0)],
#  11023: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1990, 8, 31, 0, 0)],
#  11024: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1988, 8, 31, 0, 0)],
#  11026: [datetime.datetime(1978, 9, 29, 0, 0),
#   datetime.datetime(1985, 10, 31, 0, 0)],
#  11027: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1988, 5, 31, 0, 0)],
#  11028: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1997, 12, 31, 0, 0)],
#  11029: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1988, 2, 29, 0, 0)],
#  11030: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1988, 4, 29, 0, 0)],
#  11031: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1996, 2, 29, 0, 0)],
#  11032: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1991, 8, 30, 0, 0)],
#  11033: [datetime.datetime(1963, 7, 31, 0, 0),
#   datetime.datetime(1968, 5, 31, 0, 0)],
#  11034: [datetime.datetime(1980, 6, 30, 0, 0),
#   datetime.datetime(1988, 3, 31, 0, 0)],
#  11035: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1995, 10, 31, 0, 0)],
#  11036: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1998, 9, 30, 0, 0)],
#  11037: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1996, 7, 31, 0, 0)],
#  11038: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(2012, 8, 31, 0, 0)],
#  11039: [datetime.datetime(1986, 12, 31, 0, 0),
#   datetime.datetime(1991, 10, 31, 0, 0)],
#  ...}

# %%
start_time = time.time()
store = {}

def find_stocks(target_date):
    store = []
    for ticker in dates.keys():
        if dates[ticker][0] <= target_date and dates[ticker][1] >= target_date:
            store.append(ticker)
    return store

for i in dates_month:
    store.update({i:find_stocks(i)})
    
    
print(time.time()-start_time)
# Out:
# 23.87499165534973

# %%
for date in store.keys():
    print(len(store[date]))
# Out:
# 2092
# 2089
# 2091
# 2099
# 2102
# 2112
# 2113
# 2113
# 2128
# 2135
# 2142
# 2152
# 2153
# 2158
# 2161
# 2160
# 2164
# 2170
# 2172
# 2176
# 2182
# 2185
# 2194
# 2199
# 2205
# 2205
# 2212
# 2216
# 2216
# 2216
# 2215
# 2209
# 2206
# 2221
# 2227
# 2233
# 2238
# 2235
# 2232
# 2241
# 2240
# 2241
# 2235
# 2236
# 2240
# 2242
# 2250
# 2241
# 2247
# 2247
# 2258
# 2254
# 2251
# 2254
# 2255
# 2250
# 2256
# 2260
# 2263
# 2265
# 2259
# 2248
# 2257
# 2264
# 2267
# 2274
# 2284
# 2287
# 2301
# 2306
# 2319
# 2328
# 2345
# 2354
# 2359
# 2364
# 2376
# 2383
# 2396
# 2409
# 2420
# 2430
# 2437
# 2443
# 2442
# 2449
# 2460
# 2474
# 2481
# 2493
# 2493
# 2495
# 2510
# 2524
# 2531
# 2542
# 2549
# 2562
# 2572
# 2589
# 2610
# 2626
# 2638
# 2651
# 2666
# 2687
# 2691
# 2704
# 2722
# 2735
# 2737
# 2756
# 5751
# 5798
# 5843
# 5853
# 5844
# 5818
# 5794
# 5752
# 5731
# 5710
# 5691
# 5675
# 5661
# 5605
# 5556
# 5541
# 5534
# 5523
# 5508
# 5477
# 5451
# 5436
# 5411
# 5396
# 5377
# 5362
# 5348
# 5325
# 5329
# 5326
# 5331
# 5340
# 5330
# 5328
# 5321
# 5318
# 5321
# 5325
# 5314
# 5310
# 5315
# 5314
# 5315
# 5318
# 5323
# 5333
# 5336
# 5331
# 5333
# 5338
# 5317
# 5309
# 5311
# 5307
# 5314
# 5306
# 5301
# 5283
# 5272
# 5261
# 5254
# 5253
# 5236
# 5204
# 5204
# 5205
# 5202
# 5184
# 5170
# 5183
# 5172
# 5160
# 5155
# 5154
# 5144
# 5131
# 5119
# 5126
# 5117
# 5114
# 5098
# 5084
# 5074
# 5076
# 5092
# 5109
# 5110
# 5095
# 5096
# 5108
# 5121
# 5145
# 5167
# 5202
# 5223
# 5237
# 5277
# 5309
# 5318
# 5346
# 5394
# 5440
# 5491
# 5552
# 5566
# 5589
# 5617
# 5635
# 5654
# 5657
# 5654
# 5651
# 5648
# 5639
# 5627
# 5629
# 5619
# 5611
# 5608
# 5785
# 5810
# 5806
# 5809
# 5828
# 5861
# 5903
# 5975
# 6049
# 6120
# 6189
# 6252
# 6307
# 6414
# 6468
# 6503
# 6533
# 6545
# 6570
# 6604
# 6611
# 6614
# 6609
# 6620
# 6613
# 6606
# 6602
# 6587
# 6571
# 6580
# 6587
# 6607
# 6614
# 6614
# 6631
# 6645
# 6674
# 6690
# 6667
# 6653
# 6640
# 6671
# 6723
# 6797
# 6854
# 6893
# 6922
# 6970
# 7022
# 7082
# 7090
# 7073
# 7108
# 7163
# 7209
# 7299
# 7387
# 7442
# 7488
# 7506
# 7492
# 7468
# 7430
# 7413
# 7404
# 7384
# 7380
# 7382
# 7346
# 7341
# 7331
# 7326
# 7287
# 7286
# 7268
# 7211
# 7183
# 7166
# 7151
# 7156
# 7144
# 7105
# 7096
# 7068
# 7065
# 7075
# 7051
# 7027
# 7024
# 7039
# 7042
# 7040
# 7048
# 7026
# 6995
# 6962
# 6945
# 6919
# 6898
# 6880
# 6874
# 6875
# 6897
# 6894
# 6918
# 6950
# 6940
# 6970
# 7015
# 7036
# 7045
# 7049
# 7118
# 7141
# 7154
# 7171
# 7180
# 7163
# 7109
# 7121
# 7150
# 7182
# 7203
# 7241
# 7303
# 7351
# 7395
# 7478
# 7548
# 7608
# 7654
# 7728
# 7839
# 7965
# 8019
# 8069
# 8137
# 8174
# 8248
# 8300
# 8329
# 8358
# 8377
# 8410
# 8429
# 8446
# 8441
# 8428
# 8422
# 8442
# 8446
# 8479
# 8513
# 8540
# 8535
# 8582
# 8644
# 8702
# 8699
# 8726
# 8780
# 8827
# 8914
# 8978
# 9027
# 9077
# 9089
# 9166
# 9236
# 9268
# 9275
# 9290
# 9289
# 9288
# 9285
# 9318
# 9355
# 9339
# 9325
# 9350
# 9387
# 9383
# 9372
# 9337
# 9328
# 9331
# 9318
# 9330
# 9335
# 9277
# 9204
# 9139
# 9096
# 9041
# 8997
# 8924
# 8880
# 8864
# 8819
# 8802
# 8811
# 8793
# 8753
# 8754
# 8755
# 8735
# 8659
# 8649
# 8669
# 8666
# 8631
# 8657
# 8677
# 8673
# 8645
# 8643
# 8594
# 8521
# 8441
# 8366
# 8293
# 8239
# 8182
# 8117
# 8046
# 7980
# 7924
# 7847
# 7830
# 7802
# 7734
# 7679
# 7639
# 7605
# 7572
# 7518
# 7494
# 7456
# 7416
# 7382
# 7385
# 7340
# 7314
# 7264
# 7218
# 7179
# 7123
# 7097
# 7067
# 7044
# 7020
# 6993
# 6994
# 6997
# 6974
# 6984
# 6977
# 6971
# 6980
# 6974
# 6990
# 6978
# 6958
# 6972
# 6985
# 6996
# 6982
# 6982
# 6979
# 6975
# 6981
# 6995
# 6996
# 7014
# 6999
# 6992
# 6998
# 6998
# 6976
# 6968
# 6956
# 6951
# 6970
# 7012
# 7001
# 6994
# 7000
# 7040
# 7073
# 7083
# 7084
# 7124
# 7126
# 7143
# 7187
# 7196
# 7204
# 7185
# 7159
# 7180
# 7204
# 7210
# 7185
# 7169
# 7164
# 7142
# 7141
# 7132
# 7122
# 7103
# 7070
# 7040
# 7022
# 6988
# 6955
# 6911
# 6876
# 6840
# 6807
# 6790
# 6759
# 6728
# 6727
# 6730
# 6752
# 6754
# 6750
# 6736
# 6741
# 6763
# 6748
# 6768
# 6773
# 6764
# 6752
# 6756
# 6765
# 6779
# 6786
# 6768
# 6782
# 6812
# 6844
# 6849
# 6855
# 6837
# 6835
# 6845
# 6859
# 6852
# 6854
# 6881
# 6891
# 6898
# 6900
# 6895
# 6904
# 6897
# 6873
# 6863
# 6850
# 6805
# 6797
# 6772
# 6773
# 6781
# 6794
# 6804
# 6820
# 6830
# 6840
# 6890
# 6930
# 6919
# 6927
# 6952
# 6985
# 6997
# 7017
# 7060
# 7095
# 7118
# 7133
# 7176
# 7199
# 7196
# 7189
# 7187
# 7179
# 7190
# 7208
# 7256
# 7319
# 7342
# 7347
# 7352
# 7369
# 7356
# 7351
# 7327
# 7312
# 7323
# 7324
# 7316
# 7316
# 7307
# 7327
# 7308
# 7287
# 7288
# 7291
# 7271
# 7291
# 7304
# 7313
# 7334
# 7348
# 7343
# 7342
# 7381
# 7394
# 7388
# 7403
# 7408
# 7429
# 7499
# 7515
# 7484
# 7511
